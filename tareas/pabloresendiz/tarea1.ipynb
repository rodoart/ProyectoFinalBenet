# %% [markdown]
# # Tarea 1. Tutorial  GitHub

# %% [markdown]
# # 1.- Introduction Sequence
#
# ### Ejercicio 3
#
# Primero creé la rama _bugFix_ y checkoutée a ella para crear un commit . Luego cambié a master,cree otro commit y finalmente hice merge a _BugFix_ desde master. Estos son los comandos utilizados:
#
# git checkout bugFix
#
# git commit
#
# git checkout master
#
# git commit
#
# git merge bugFix
#
#
#
# A continuación la [Imagen](imagenes/ej31.png). que lo sustenta.
#
#
# ### Ejercicio 4
# Creé la rama _BugFix_ , comitée , regresé a master y comitée de nuevo. Regresé a _bugFix_ e hice rebase sobre master.  Estos son los comandos utilizados:
#
# git checkout -b bugFix
#
# git commit
#
# git checkout master
#
# git commit
#
# git checkout bugFix
#
#
# git rebase master
#
#
# Aquí la [Imagen](imagenes/ej41.png).
#
# # 2.- Ramping up
#
# ### Ejercicio 3
# Moví la rama _bugFix_ a C0, luego salí a C6 y desde ahí moví a master. Finalmente salí a C1 para completar el nivel. Aquí el código:
#
#
# git branch -f bugFix C0
#
# git branch -f master C6
#
# git checkout C1
#
# Aquí la [Imagen](imagenes/imagen3.png).
#
# ### Ejercicio 4
# Resetée la rama local , salí a la rama _pushed_ e hice revert.
#
# git reset HEAD~1
#
# git checkout pushed
#
# git revert HEAD
#
# Aquí la [Imagen](imagenes/ej42.png).
#
# # 3.- Moving work around
# ### Ejercicio 1
# Moví los commits que se indican con el siguiente comando:
#
# git cherry-pick C3 C4 C7
#
# Aquí la [Imagen](imagenes/imagen4.png).
#
# ### Ejercicio 2
#
# Con la ayuda de la interfaz interactiva, moví los commits en el orden necesario con el siguiente comando:
#
# git rebase -i HEAD~4
#
# Aquí la [Imagen](imagenes/imagen5.png)
#
# # 4.- A mixed bag
#
# ### Ejercicio 1
# Me moví a master y desde ahí jalé C4.
#
# git checkout master
#
# git cherry-pick C4
#
# Aquí la [Imagen](imagenes/imag6.png)
#
#
# ### Ejercicio 3
# Me moví a master, jalé C2, lo commitée y después jalé C3:
#
# git checkout master
#
# git cherry-pick C2
#
# git commit --amend
#
# git cherry-pick C3
#
#
#
# Aquí la [Imagen](imagenes/imag7.png) .
#
#
# ### Ejercicio 4
#
# Marqué las ramas C2 y C1 con el siguiente comando:
#
#
# git tag v0 C1
#
# git tag v1 C!
#
# git checkout v1
#
#
# Aquí la [Imagen](imagenes/imag8.png) .
#
# # 5.- Advanced topics
#
# ## Ejercicio 2
# Creé una nueva rama de nombre _bugWork_ y la moví al commit C2:
#
#
# git branch bugWork C2
#
#
# Aquí la [Imagen](imagenes/imag9.png) .
#
# ## Ejercicio 3
#
# Acomodé la rama _three_ al commit requerido, despues me moví a C1 y desde ahí jalé los commits C4, C3 y C2. Luego moví la rama _one_ a C2'. Regresé a C1 y desdé ahí jalé los commits requeridos, en el orden mostrado en la imagen. Finalmente jalé la rama _two_ a C2'':
#
# git branch -f three C2
#
# git checkout C1
#
# git cherry-pick C4 C3 C2
#
# git branch -f one C2'
#
# git checkout C1
#
# git cherry-pick C5 C4' C3' C2'
#
# git branch -f two C2''
#
# Aquí la [Imagen](imagenes/imag10.png) .
